# %% [markdown]
# # WEB USAGE

# %%
import pandas as pd

# Ganti path file sesuai lokasi datamu
df = pd.read_csv('data.csv')

print(df.head())
print(df.info())
# Out:
#    Unnamed: 0         host       time method                           url  \
# 0           0  ***.novo.dk  805465029    GET                     /ksc.html
# 1           1  ***.novo.dk  805465031    GET    /images/ksclogo-medium.gif
# 2           2  ***.novo.dk  805465051    GET  /images/MOSAIC-logosmall.gif
# 3           3  ***.novo.dk  805465053    GET     /images/USA-logosmall.gif
# 4           4  ***.novo.dk  805465054    GET    /images/NASA-logosmall.gif
#
#    response  bytes
# 0       200   7067
# 1       200   5866
# 2       200    363
# 3       200    234
# 4       200    786
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2965561 entries, 0 to 2965560
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   host        object
#  2   time        int64
#  3   method      object
#  4   url         object
#  5   response    int64
#  6   bytes       int64
# dtypes: int64(4), object(3)
# memory usage: 158.4+ MB
# ...

# %% [markdown]
# ## Filterisasi
